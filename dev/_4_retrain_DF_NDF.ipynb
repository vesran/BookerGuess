# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
users = pd.read_csv('../data/train_users_2.csv')
test_users = pd.read_csv('../data/test_users.csv')
sessions = pd.read_csv('../data/sessions.csv')

# %%
users['target'] = users.apply(lambda r: 1 if r['country_destination'] != 'NDF' else 0, axis=1)

# %%
users.groupby('target')['id'].count()
# Out:
# target
# 0    124543
# 1     88908
# Name: id, dtype: int64

# %%
users = pd.concat([users[users['target'] == 0].head(88000), users[users['target'] == 1].head(88000)])

# %%
users = users.sample(frac=1)

# %%
users['gender_revealed'] = ((users['gender'] != '-unknown-') & (users['gender'] != 'OTHER'))

# %%
def process_age(age):
    if age > 1000:
        return 2015 - age
    elif age < 100:
        return age
    else: 
        return -1

users['age'] = users.apply(lambda r: process_age(r['age']), axis=1)
users['age_group'] = sum([(users['age'] < 0).astype(int),
    (users['age'] < 18).astype(int),
    (users['age'] < 25).astype(int),
    (users['age'] < 30).astype(int),
    (users['age'] < 35).astype(int),
    (users['age'] < 40).astype(int),
    (users['age'] < 60).astype(int),
    (users['age'] < 100).astype(int)])

# %%
users['signup_flow_group'] = sum([
    (users['signup_flow'] < 3),
    (users['signup_flow'] < 7),
    (users['signup_flow'] < 100)
])

# %%
kept_aff_channels = set(['api', 'other', 'content'])

users['affiliate_channel_group'] = users.apply(lambda r: r['affiliate_channel'] if r['affiliate_channel'] in kept_aff_channels else 'unimportant', axis=1)

# %%
kept_first_device_types = set(['Mac Desktop', 'Other/Unknown'])

users['first_device_type_group'] = users.apply(lambda r: r['first_device_type'] if r['first_device_type'] in kept_first_device_types else 'unimportant', axis=1)

# %%
users['first_affiliate_tracked'] = users['first_affiliate_tracked'].fillna('-unknown-')

# %%
users.head()
# Out:
#                id date_account_created  timestamp_first_active  \
# 51166  l1nce2xpuv           2012-12-05          20121205202520
# 79164  ggldfdrdv5           2013-05-24          20130524011757
# 4200   k8n0y2rphe           2011-04-12          20110412203206
# 36723  3yfheape9l           2012-08-16          20120816074816
# 75448  cqbratofs5           2013-05-07          20130507161522
#
#       date_first_booking     gender   age signup_method  signup_flow language  \
# 51166                NaN     FEMALE  40.0      facebook            0       en
# 79164         2013-05-24       MALE  26.0         basic            0       en
# 4200                 NaN  -unknown-  -1.0      facebook            2       en
# 36723                NaN     FEMALE  -1.0         basic            0       en
# 75448         2013-10-26       MALE  36.0         basic            0       en
#
#       affiliate_channel  ... signup_app first_device_type  first_browser  \
# 51166            direct  ...        Web   Windows Desktop             IE
# 79164            direct  ...        Web       Mac Desktop         Chrome
# 4200             direct  ...        Web   Windows Desktop             IE
# 36723            direct  ...        Web              iPad  Mobile Safari
# 75448         sem-brand  ...        Web   Windows Desktop         Chrome
#
#       country_destination target age_group  gender_revealed  \
# 51166                 NDF      0         2             True
# 79164                  NL      1         5             True
# 4200                  NDF      0         8            False
# 36723                 NDF      0         8             True
# 75448                  US      1         3             True
#
#        signup_flow_group  affiliate_channel_group  first_device_type_group
# 51166                  3              unimportant              unimportant
# 79164                  3              unimportant              Mac Desktop
# 4200                   3              unimportant              unimportant
# 36723                  3              unimportant              unimportant
# 75448                  3              unimportant              unimportant
#
# [5 rows x 22 columns]

# %%
to_drop = ['date_first_booking', 'id', 'target', 'country_destination', 'date_account_created', 'timestamp_first_active', 
           'age', 'gender', 'signup_flow', 'affiliate_channel', 'first_device_type', 
            'language']
data = users.drop(to_drop, axis=1)

# %%
data
# Out:
#        signup_method   affiliate_provider first_affiliate_tracked signup_app  \
# 51166       facebook               direct                  linked        Web
# 79164          basic               direct                  linked        Web
# 4200        facebook               direct               untracked        Web
# 36723          basic               direct               untracked        Web
# 75448          basic               google                     omg        Web
# ...              ...                  ...                     ...        ...
# 57734       facebook  facebook-open-graph               untracked        Web
# 119297         basic               direct                  linked        Web
# 106201      facebook               google                     omg        Web
# 3716           basic               direct               untracked        Web
# 129264         basic               direct                  linked        Web
#
#         first_browser  age_group  gender_revealed  signup_flow_group  \
# 51166              IE          2             True                  3
# 79164          Chrome          5             True                  3
# 4200               IE          8            False                  3
# 36723   Mobile Safari          8             True                  3
# 75448          Chrome          3             True                  3
# ...               ...        ...              ...                ...
# 57734         Firefox          2             True                  3
# 119297             IE          8            False                  3
# 106201         Chrome          5             True                  3
# 3716               IE          3            False                  3
# 129264             IE          8            False                  3
#
#        affiliate_channel_group first_device_type_group
# 51166              unimportant             unimportant
# 79164              unimportant             Mac Desktop
# 4200               unimportant             unimportant
# 36723              unimportant             unimportant
# 75448              unimportant             unimportant
# ...                        ...                     ...
# 57734                    other             Mac Desktop
# 119297             unimportant             unimportant
# 106201             unimportant             unimportant
# 3716               unimportant             unimportant
# 129264             unimportant             unimportant
#
# [176000 rows x 10 columns]

# %%
X = pd.get_dummies(data)
y = users['target']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(max_depth=14)
np.mean(cross_val_score(model, X, y, cv=4))
# Out:
# 0.6819034090909091
